# %%
import numpy as np
import pandas as pd

# %%
movie_df = pd.read_csv(r"C:\Users\rudra\LMS\Movie.csv")
movie_df.head()
# Out:
#    userId             movie  rating
# 0       3  Toy Story (1995)     4.0
# 1       6  Toy Story (1995)     5.0
# 2       8  Toy Story (1995)     4.0
# 3      10  Toy Story (1995)     4.0
# 4      11  Toy Story (1995)     4.5

# %%
movie_df.shape
# Out:
# (8992, 3)

# %%
movie_df[0:5]
# Out:
#    userId             movie  rating
# 0       3  Toy Story (1995)     4.0
# 1       6  Toy Story (1995)     5.0
# 2       8  Toy Story (1995)     4.0
# 3      10  Toy Story (1995)     4.0
# 4      11  Toy Story (1995)     4.5

# %%
movie_df[movie_df['userId']==6]
# Out:
#       userId                    movie  rating
# 1          6         Toy Story (1995)     5.0
# 3725       6  Grumpier Old Men (1995)     3.0
# 6464       6           Sabrina (1995)     5.0

# %%
movie_df[movie_df['userId']==11]
# Out:
#       userId             movie  rating
# 4         11  Toy Story (1995)     4.5
# 7446      11  GoldenEye (1995)     2.5

# %%
len(movie_df.userId.unique())
# Out:
# 4081

# %%
len(movie_df.movie.unique())
# Out:
# 10

# %%
user_movie=movie_df.pivot(index='userId',
                         columns='movie',
                         values='rating').reset_index(drop=True)

# %%
user_movie
# Out:
# movie  Father of the Bride Part II (1995)  GoldenEye (1995)  \
# 0                                     NaN               NaN
# 1                                     NaN               NaN
# 2                                     NaN               NaN
# 3                                     NaN               4.0
# 4                                     NaN               NaN
# ...                                   ...               ...
# 4076                                  4.0               NaN
# 4077                                  3.5               NaN
# 4078                                  NaN               3.0
# 4079                                  NaN               NaN
# 4080                                  NaN               NaN
#
# movie  Grumpier Old Men (1995)  Heat (1995)  Jumanji (1995)  Sabrina (1995)  \
# 0                          NaN          NaN             3.5             NaN
# 1                          4.0          NaN             NaN             NaN
# ...
